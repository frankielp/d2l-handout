# %%
# %matplotlib inline
from d2l import mxnet as d2l
from mxnet import np, npx
import random
npx.set_np()

# %%
fair_probs = [1.0 / 6] * 6
np.random.multinomial(1, fair_probs)
# Out:
# array([0, 0, 0, 1, 0, 0], dtype=int64)

# %%
np.random.multinomial(10, fair_probs)
# Out:
# array([2, 1, 2, 3, 1, 1], dtype=int64)

# %%
counts = np.random.multinomial(10, fair_probs, size=3)
counts
# Out:
# array([[1, 2, 1, 2, 4, 0],
#        [3, 2, 2, 1, 0, 2],
#        [1, 2, 1, 3, 1, 2]], dtype=int64)

# %%
# Store the results as 32-bit floats for division
counts = np.random.multinomial(1000, fair_probs).astype(np.float32)
counts / 1000  # Reletive frequency as the estimate
# Out:
# array([0.167, 0.155, 0.177, 0.16 , 0.166, 0.175])

# %%
counts = np.random.multinomial(10, fair_probs, size=500)
cum_counts = counts.astype(np.float32).cumsum(axis=0)
estimates = cum_counts / cum_counts.sum(axis=1, keepdims=True)

d2l.set_figsize((6, 4.5))
for i in range(6):
    d2l.plt.plot(estimates[:, i].asnumpy(),
                 label=("P(die=" + str(i + 1) + ")"))
d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
d2l.plt.gca().set_xlabel('Groups of experiments')
d2l.plt.gca().set_ylabel('Estimated probability')
d2l.plt.legend();

# %% [markdown]
# # Bayes Theorem

# %% [markdown]
# $$ P(A \mid B) = \frac{P(B \mid A) P(A)}{P(B)}. $$

# %% [markdown]
# # Tóm tắt
#
# Chúng ta có thể sử dụng MXNet để lấy mẫu từ phân phối xác suất.
#
# Các biến ngẫu nhiên có thể được phân tích bằng các phương pháp như phân phối đồng thời (joint distribution), phân phối có điều kiện (conditional distribution), định lý Bayes, phép biên hóa (marginalization) và giả định độc lập (independence assumptions).
#
# Kỳ vọng và phương sai là các phép đo hữu ích để tóm tắt các đặc điểm chính của phân phối xác suất.

# %% [markdown]
# # Exercise

# %%
exp=np.random.multinomial(500,fair_probs,size=10)
cum_counts = exp.astype(np.float32).cumsum(axis=0)
estimates = cum_counts / cum_counts.sum(axis=1, keepdims=True)

d2l.set_figsize((6, 4.5))
for i in range(6):
    d2l.plt.plot(estimates[:, i].asnumpy(),
                 label=("P(die=" + str(i + 1) + ")"))
d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
d2l.plt.gca().set_xlabel('Groups of experiments')
d2l.plt.gca().set_ylabel('Estimated probability')
d2l.plt.legend();

# %%
# !conda create --name d2l python=3.9 -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/juicydoggo/opt/anaconda3/envs/d2l
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pip-23.0.1                 |   py39hecd8cb5_0         2.5 MB
#     python-3.9.16              |       h218abb5_2        12.7 MB
#     sqlite-3.41.1              |       h6c40b1e_0         1.2 MB
#     ------------------------------------------------------------
#                                            Total:        16.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   ca-certificates    pkgs/main/osx-64::ca-certificates-2023.01.10-hecd8cb5_0 None
#   certifi            pkgs/main/osx-64::certifi-2022.12.7-py39hecd8cb5_0 None
#   libcxx             pkgs/main/osx-64::libcxx-14.0.6-h9765a3e_0 None
#   libffi             pkgs/main/osx-64::libffi-3.4.2-hecd8cb5_6 None
#   ncurses            pkgs/main/osx-64::ncurses-6.4-hcec6c5f_0 None
#   openssl            pkgs/main/osx-64::openssl-1.1.1t-hca72f7f_0 None
#   pip                pkgs/main/osx-64::pip-23.0.1-py39hecd8cb5_0 None
#   python             pkgs/main/osx-64::python-3.9.16-h218abb5_2 None
#   readline           pkgs/main/osx-64::readline-8.2-hca72f7f_0 None
#   setuptools         pkgs/main/osx-64::setuptools-65.6.3-py39hecd8cb5_0 None
#   sqlite             pkgs/main/osx-64::sqlite-3.41.1-h6c40b1e_0 None
#   tk                 pkgs/main/osx-64::tk-8.6.12-h5d9f67b_0 None
#   tzdata             pkgs/main/noarch::tzdata-2022g-h04d1e81_0 None
#   wheel              pkgs/main/osx-64::wheel-0.38.4-py39hecd8cb5_0 None
#   xz                 pkgs/main/osx-64::xz-5.2.10-h6c40b1e_1 None
#   zlib               pkgs/main/osx-64::zlib-1.2.13-h4dc903c_0 None
#
#
#
# Downloading and Extracting Packages
# python-3.9.16        | 12.7 MB   | ##################################### | 100%
# pip-23.0.1           | 2.5 MB    | ##################################### | 100%
# sqlite-3.41.1        | 1.2 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate d2l
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done

# %%
# !source activate d2l
# !pip install torch==1.12.0 torchvision==0.13.0
# !pip install d2l==1.0.0b0
# Out:
# Collecting torch==1.12.0
#   Downloading torch-1.12.0-cp38-none-macosx_10_9_x86_64.whl (137.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 MB 7.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting torchvision==0.13.0
#   Downloading torchvision-0.13.0-cp38-cp38-macosx_10_9_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.4 MB/s eta 0:00:000m eta 0:00:010:01:01
# Requirement already satisfied: typing-extensions in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from torch==1.12.0) (4.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from torchvision==0.13.0) (9.4.0)
# Requirement already satisfied: requests in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from torchvision==0.13.0) (2.25.1)
# Requirement already satisfied: numpy in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from torchvision==0.13.0) (1.21.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from requests->torchvision==0.13.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from requests->torchvision==0.13.0) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from requests->torchvision==0.13.0) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from requests->torchvision==0.13.0) (4.0.0)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1
#     Uninstalling torchvision-0.14.1:
#       Successfully uninstalled torchvision-0.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.1 requires torch==1.9.1, but you have torch 1.12.0 which is incompatible.
# Successfully installed torch-1.13.1 torchvision-0.13.0
# Collecting d2l==1.0.0b0
#   Downloading d2l-1.0.0b0-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.6/141.6 kB 1.5 MB/s eta 0:00:002.0 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib-inline in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from d2l==1.0.0b0) (0.1.6)
# Collecting gpytorch
#   Downloading gpytorch-1.9.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 3.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from d2l==1.0.0b0) (1.21.5)
# Requirement already satisfied: jupyter in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from d2l==1.0.0b0) (1.0.0)
# Requirement already satisfied: requests in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from d2l==1.0.0b0) (2.25.1)
# Requirement already satisfied: pandas in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from d2l==1.0.0b0) (1.2.4)
# Requirement already satisfied: scipy in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from d2l==1.0.0b0) (1.7.1)
# Collecting gym==0.21.0
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 8.4 MB/s eta 0:00:009.7 MB/s eta 0:00:01m
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from d2l==1.0.0b0) (3.5.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from gym==0.21.0->d2l==1.0.0b0) (2.0.0)
# Collecting linear-operator>=0.2.0
#   Downloading linear_operator-0.3.0-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from gpytorch->d2l==1.0.0b0) (1.1.1)
# Requirement already satisfied: notebook in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jupyter->d2l==1.0.0b0) (6.4.3)
# Requirement already satisfied: ipykernel in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jupyter->d2l==1.0.0b0) (6.2.0)
# Requirement already satisfied: jupyter-console in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jupyter->d2l==1.0.0b0) (6.4.0)
# Requirement already satisfied: qtconsole in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jupyter->d2l==1.0.0b0) (5.1.1)
# Requirement already satisfied: ipywidgets in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jupyter->d2l==1.0.0b0) (7.6.4)
# Requirement already satisfied: nbconvert in /Users/juicydoggo/.local/lib/python3.8/site-packages (from jupyter->d2l==1.0.0b0) (7.2.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->d2l==1.0.0b0) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->d2l==1.0.0b0) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->d2l==1.0.0b0) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->d2l==1.0.0b0) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->d2l==1.0.0b0) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->d2l==1.0.0b0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->d2l==1.0.0b0) (3.0.9)
# Requirement already satisfied: traitlets in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib-inline->d2l==1.0.0b0) (5.1.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from pandas->d2l==1.0.0b0) (2022.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from requests->d2l==1.0.0b0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from requests->d2l==1.0.0b0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from requests->d2l==1.0.0b0) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from requests->d2l==1.0.0b0) (2022.12.7)
# Requirement already satisfied: torch>=1.11 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from linear-operator>=0.2.0->gpytorch->d2l==1.0.0b0) (1.13.1)
# Requirement already satisfied: six>=1.5 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->d2l==1.0.0b0) (1.16.0)
# Requirement already satisfied: jupyter-client<8.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==1.0.0b0) (7.3.5)
# Requirement already satisfied: appnope in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==1.0.0b0) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==1.0.0b0) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==1.0.0b0) (6.2)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==1.0.0b0) (7.27.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets->jupyter->d2l==1.0.0b0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets->jupyter->d2l==1.0.0b0) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets->jupyter->d2l==1.0.0b0) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets->jupyter->d2l==1.0.0b0) (1.0.0)
# Requirement already satisfied: pygments in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jupyter-console->jupyter->d2l==1.0.0b0) (2.10.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jupyter-console->jupyter->d2l==1.0.0b0) (3.0.20)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (1.5.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/juicydoggo/.local/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (2.0.4)
# Requirement already satisfied: bleach in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (4.0.0)
# Requirement already satisfied: jinja2>=3.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (3.1.2)
# Requirement already satisfied: tinycss2 in /Users/juicydoggo/.local/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (1.2.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (4.11.3)
# Requirement already satisfied: defusedxml in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (0.7.1)
# Requirement already satisfied: markupsafe>=2.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (4.11.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==1.0.0b0) (0.5.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->d2l==1.0.0b0) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->d2l==1.0.0b0) (23.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->d2l==1.0.0b0) (0.13.1)
# Requirement already satisfied: prometheus-client in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->d2l==1.0.0b0) (0.14.1)
# Requirement already satisfied: argon2-cffi in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->d2l==1.0.0b0) (21.3.0)
# Requirement already satisfied: qtpy in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from qtconsole->jupyter->d2l==1.0.0b0) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->gpytorch->d2l==1.0.0b0) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->gpytorch->d2l==1.0.0b0) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter->d2l==1.0.0b0) (3.8.0)
# Requirement already satisfied: pickleshare in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->d2l==1.0.0b0) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->d2l==1.0.0b0) (58.0.4)
# Requirement already satisfied: decorator in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->d2l==1.0.0b0) (5.1.1)
# Requirement already satisfied: backcall in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->d2l==1.0.0b0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->d2l==1.0.0b0) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->d2l==1.0.0b0) (0.17.2)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter->d2l==1.0.0b0) (1.5.5)
# Requirement already satisfied: entrypoints in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter->d2l==1.0.0b0) (0.4)
# Requirement already satisfied: async-generator in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbclient>=0.5.0->nbconvert->jupyter->d2l==1.0.0b0) (1.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->d2l==1.0.0b0) (3.2.0)
# Requirement already satisfied: wcwidth in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->d2l==1.0.0b0) (0.2.5)
# Requirement already satisfied: ptyprocess in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from terminado>=0.8.3->notebook->jupyter->d2l==1.0.0b0) (0.7.0)
# Requirement already satisfied: typing-extensions in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.11->linear-operator>=0.2.0->gpytorch->d2l==1.0.0b0) (4.4.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter->d2l==1.0.0b0) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->jupyter->d2l==1.0.0b0) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->d2l==1.0.0b0) (0.5.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->jupyter->d2l==1.0.0b0) (0.7.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->d2l==1.0.0b0) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->d2l==1.0.0b0) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->d2l==1.0.0b0) (1.15.1)
# Requirement already satisfied: pycparser in /Users/juicydoggo/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->d2l==1.0.0b0) (2.21)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616829 sha256=d7b38702744f90692fb65055a8be5857b6afbb826f61fec250ffb0b9a0737da8
#   Stored in directory: /Users/juicydoggo/Library/Caches/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
# Successfully built gym
# Installing collected packages: gym, linear-operator, gpytorch, d2l
#   Attempting uninstall: d2l
#     Found existing installation: d2l 0.17.6
#     Uninstalling d2l-0.17.6:
#       Successfully uninstalled d2l-0.17.6
# Successfully installed d2l-1.0.0b0 gpytorch-1.9.1 gym-0.21.0 linear-operator-0.3.0
